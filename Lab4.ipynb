# %% [markdown]
# <a href="https://colab.research.google.com/github/federicofaria/Repo-test/blob/main/Lab4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # IS 4487 Module 2 Script
#
# ## Agenda
#
# - Loading installed packages
# - Inspect data
# - Explore plot types
#
# Make sure you have downloaded tonight's script and data from Canvas.

# %% [markdown]
# ##Load Libraries
#
# In this class we will be using
# - Pandas
# - Scikitlearn
# - Matplotlib
#
# We can pull sample data from
# - statsmodels.api

# %%
import pandas as pd
import matplotlib as mpl
import sklearn as sl

# %% [markdown]
# ## Getting data into Pandas
#
# In this case we will load data from the statsmodels.org library
#
# See the Canvas assignments and lectures for a description of the Megatelco data
#
# **Note:** you will need to enter a code supplied by Google in the next step.

# %%
from google.colab import drive
import re 
drive.mount('/content/gdrive', force_remount=True)

df = pd.read_csv (r'/content/gdrive/MyDrive/IS 4487/Twitter_dataset.csv', encoding = 'latin1')

print (df)
# Out:
# Mounted at /content/gdrive
#       Unnamed: 0                       _id                      created_at  \
# 0              0  6020fc7e9e1aa8e3e7ad0832  Mon Feb 08 04:29:58 +0000 2021
# 1              1  6020fc7e9e1aa8e3e7ad0833  Mon Feb 08 04:29:55 +0000 2021
# 2              2  6020fc7e9e1aa8e3e7ad0834  Mon Feb 08 04:29:48 +0000 2021
# 3              3  6020fc7e9e1aa8e3e7ad0835  Mon Feb 08 04:29:43 +0000 2021
# 4              4  6020fc7e9e1aa8e3e7ad0836  Mon Feb 08 04:29:42 +0000 2021
# ...          ...                       ...                             ...
# 9751           3  6020fbb89e1aa8e3e7ac0a78  Mon Feb 08 02:01:58 +0000 2021
# 9752           4  6020fbb89e1aa8e3e7ac0a79  Mon Feb 08 01:00:24 +0000 2021
# 9753           5  6020fbb89e1aa8e3e7ac0a7a  Sun Feb 07 23:44:20 +0000 2021
# 9754           6  6020fbb89e1aa8e3e7ac0a7b  Sun Feb 07 23:33:40 +0000 2021
# 9755           7  6020fbb89e1aa8e3e7ac0a7c  Sun Feb 07 23:32:32 +0000 2021
#
# ...

# %%
#look at the top rows
df.head(10)
# Out:
#    Unnamed: 0                       _id                      created_at  \
# 0           0  6020fc7e9e1aa8e3e7ad0832  Mon Feb 08 04:29:58 +0000 2021
# 1           1  6020fc7e9e1aa8e3e7ad0833  Mon Feb 08 04:29:55 +0000 2021
# 2           2  6020fc7e9e1aa8e3e7ad0834  Mon Feb 08 04:29:48 +0000 2021
# 3           3  6020fc7e9e1aa8e3e7ad0835  Mon Feb 08 04:29:43 +0000 2021
# 4           4  6020fc7e9e1aa8e3e7ad0836  Mon Feb 08 04:29:42 +0000 2021
# 5           5  6020fc7e9e1aa8e3e7ad0837  Mon Feb 08 04:29:40 +0000 2021
# 6           6  6020fc7e9e1aa8e3e7ad0838  Mon Feb 08 04:29:40 +0000 2021
# 7           7  6020fc7e9e1aa8e3e7ad0839  Mon Feb 08 04:29:37 +0000 2021
# 8           8  6020fc7e9e1aa8e3e7ad083a  Mon Feb 08 04:29:36 +0000 2021
# 9           9  6020fc7e9e1aa8e3e7ad083b  Mon Feb 08 04:29:35 +0000 2021
#
#              id               id_str  \
# 0  1.358630e+18  1358634152719839233
# 1  1.358630e+18  1358634138639605762
# 2  1.358630e+18  1358634110600826880
# ...

# %%
#look at last rows
df.tail(10)

# %%
#get a summary of the dataset
df.describe()

# %%
#look at the datatypes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9756 entries, 0 to 9755
# Data columns (total 39 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Unnamed: 0                 9756 non-null   int64
#  1   _id                        9756 non-null   object
#  2   created_at                 9756 non-null   object
#  3   id                         9756 non-null   float64
#  4   id_str                     9756 non-null   int64
#  5   text                       9756 non-null   object
#  6   display_text_range         3222 non-null   object
#  7   source                     9747 non-null   object
#  8   truncated                  9756 non-null   bool
#  9   in_reply_to_status_id      2863 non-null   float64
#  10  in_reply_to_status_id_str  2863 non-null   float64
#  11  in_reply_to_user_id        2985 non-null   float64
#  12  in_reply_to_user_id_str    2985 non-null   float64
# ...

# %% [markdown]
# ## Clean up the data
# Total amount parse

# %%
#REGEX did not entirely work, so casting into string and using string's methods worked better
df_clean = df[(df['text'].str.contains('M&amp;M')) | (df['text'].str.contains('M&amp;m')) | (df['text'].str.contains('m&amp;m'))]
#df_clean = df[(re.search('M&amp;M', df['text'])) | (re.search('M&amp;m', df['text'])) | (re.search('m&amp;m', df['text']))]
#df_clean = df[(df['house'] > 0) & (df['income'] > 0) & (df['handset_price'] < 1000)]
df_clean.describe()
# Out:
#         Unnamed: 0            id        id_str  in_reply_to_status_id  \
# count  5330.000000  5.330000e+03  5.330000e+03           7.090000e+02
# mean   5606.911632  1.358583e+18  1.358584e+18           1.358393e+18
# std    2691.095777  2.230124e+13  2.139889e+13           3.649895e+15
# min       1.000000  1.358560e+18  1.358559e+18           1.264730e+18
# 25%    3455.000000  1.358560e+18  1.358564e+18           1.358560e+18
# 50%    6061.000000  1.358580e+18  1.358576e+18           1.358570e+18
# 75%    8006.750000  1.358600e+18  1.358600e+18           1.358590e+18
# max    9625.000000  1.358630e+18  1.358634e+18           1.358630e+18
#
#        in_reply_to_status_id_str  in_reply_to_user_id  \
# count               7.090000e+02         7.370000e+02
# mean                1.358393e+18         3.093774e+17
# std                 3.649673e+15         4.980012e+17
# min                 1.264735e+18         2.682300e+04
# 25%                 1.358563e+18         4.245162e+07
# ...

# %% [markdown]
# # Add Derived Attribute
#
# Add a column with the income in K (thousands)

# %%
df_clean['income_k'] = (df_clean['income']/1000).round(2)
df_clean.head()

# %% [markdown]
# ## Slice the data
#  What is average house price at the two levels of leave?
#
#  Conclusion?  Stayers have substantially more expensive homes.

# %%
df_clean[['house','leave']].groupby('leave').mean().round(2)

# %% [markdown]
# The mostly wrong dataset

# %%
from zmq.constants import NULL
df_unclean = df[(df['house'] < 0) | (df['income'] < 0) | (df['handset_price'] > 1000) | (df['over_15mins_calls_per_month'] == NULL) ]
df_unclean.describe()
# Out:
#               income     overage    leftover           house  handset_price  \
# count     861.000000  861.000000  861.000000      861.000000   8.610000e+02
# mean    81931.883856   12.656214   24.721254   493336.360046   2.718613e+03
# std     42508.707315   43.691735   27.352928   259953.441543   6.815464e+04
# min    -28811.000000    0.000000    0.000000  -796132.000000   1.300000e+02
# 25%     40982.000000    0.000000    0.000000   265302.000000   2.190000e+02
# 50%     80209.000000    0.000000   15.000000   453678.000000   3.310000e+02
# 75%    118128.000000    0.000000   45.000000   712681.000000   5.470000e+02
# max    159716.000000  257.000000   89.000000  1000000.000000   2.000234e+06
#
#        over_15mins_calls_per_month  average_call_duration            id
# count                   861.000000             861.000000    861.000000
# mean                      0.058072               5.944251  10287.982578
# ...

# %% [markdown]
# Wow, it's completely useless, let's see some more :)

# %%
df_unclean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 861 entries, 3 to 4993
# Data columns (total 13 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   college                      861 non-null    object
#  1   income                       861 non-null    int64
#  2   overage                      861 non-null    int64
#  3   leftover                     861 non-null    int64
#  4   house                        861 non-null    int64
#  5   handset_price                861 non-null    int64
#  6   over_15mins_calls_per_month  861 non-null    float64
#  7   average_call_duration        861 non-null    int64
#  8   reported_satisfaction        861 non-null    object
#  9   reported_usage_level         861 non-null    object
#  10  considering_change_of_plan   861 non-null    object
#  11  leave                        861 non-null    object
#  12  id                           861 non-null    int64
# ...

# %%
df_unclean.plot.scatter(x='house',y='handset_price',c='income')
#whoah, that's a lot of negative values

# %%
df_unclean['over_15mins_calls_per_month'].plot.box(color ='red', ylabel = 'Now thats painful', title = 'Calls')
#Horrendous

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
